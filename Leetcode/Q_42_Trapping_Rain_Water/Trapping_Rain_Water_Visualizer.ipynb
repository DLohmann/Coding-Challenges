# %%
from matplotlib import pyplot as plt

# %%
y = [6,8,5,0,0,6,5]
x = [i for i in range(len(y))]
plt.bar(x, y, width=1, color='black')
plt.grid(axis='y')
plt.xticks(x)
plt.yticks([k for k in range(max(y) + 1)])
plt.show()
